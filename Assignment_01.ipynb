# %%
215510P-Athapaththu AAND

# %%
pip install numpy matplotlib scikit-learn opencv-python reportlab Pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 36.6 MB/s eta 0:00:00a 0:00:01
# ...
